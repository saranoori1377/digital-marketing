# %%
# !pip install requests
# !pip install beautifulsoup4
# !pip install pandas
# !pip install fake-useragent
# !pip install lxml
# Out:
# Requirement already satisfied: requests in c:\users\saeid\anaconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\saeid\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\saeid\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\saeid\anaconda3\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saeid\anaconda3\lib\site-packages (from requests) (2024.2.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\saeid\anaconda3\lib\site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\saeid\anaconda3\lib\site-packages (from beautifulsoup4) (2.4)
# Requirement already satisfied: pandas in c:\users\saeid\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\saeid\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\saeid\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\saeid\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\saeid\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\saeid\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Collecting fake-useragent
#   Obtaining dependency information for fake-useragent from https://files.pythonhosted.org/packages/e4/99/60d8cf1b26938c2e0a57e232f7f15641dfcd6f8deda454d73e4145910ff6/fake_useragent-1.5.1-py3-none-any.whl.metadata
#   Downloading fake_useragent-1.5.1-py3-none-any.whl.metadata (15 kB)
# Downloading fake_useragent-1.5.1-py3-none-any.whl (17 kB)
# Installing collected packages: fake-useragent
# Successfully installed fake-useragent-1.5.1
# Requirement already satisfied: lxml in c:\users\saeid\anaconda3\lib\site-packages (4.9.3)

# %% [markdown]
# # Direction

# %%
#direction
import os

import os

current_directory = os.getcwd()
print("Current Directory:", current_directory)


#new_directory = r"D:\My papers\Application"  # Use the 'r' prefix to handle backslashes in Windows paths

new_directory = r"D:\My papers\Application\API_Youtube"  # Use the 'r' prefix to handle backslashes in Windows paths

# Change the current working directory
os.chdir(new_directory)

# Verify that the directory has been changed
current_directory = os.getcwd()
print("Current Directory:", current_directory)
#D:\My papers\Application\Other

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
from fake_useragent import UserAgent
import json
import scipy.io as sio
import numpy as np

def setup_scraper():
    ua = UserAgent()
    headers = {
        'User-Agent': ua.random,
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        'Accept-Language': 'en-US,en;q=0.5',
        'Connection': 'keep-alive',
        'Referer': 'https://www.amazon.com'
    }
    return headers

def search_amazon(keyword, headers):
    base_url = f"https://www.amazon.com/s?k={keyword.replace(' ', '+')}"
    
    try:
        print(f"Attempting to fetch URL: {base_url}")
        response = requests.get(base_url, headers=headers)
        print(f"Response status code: {response.status_code}")
        if response.status_code == 200:
            return response.text
        else:
            print(f"Failed to fetch data: Status code {response.status_code}")
            return None
    except Exception as e:
        print(f"Error occurred during request: {e}")
        return None

def parse_product_listing(html_content):
    if not html_content:
        print("No HTML content to parse")
        return []

    soup = BeautifulSoup(html_content, 'html.parser')
    products = []
    
    print("Parsing HTML content...")
    
    items = soup.find_all('div', {'data-component-type': 's-search-result'})
    print(f"Found {len(items)} product items")
    
    for item in items:
        try:
            product = {}
            
            # Title and Product URL
            title_elem = item.find('a', {'class': 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'})
            if title_elem:
                product['title'] = title_elem.text.strip()
                # Get the product URL
                product['url'] = 'https://www.amazon.com' + title_elem.get('href', '')
            else:
                product['title'] = 'N/A'
                product['url'] = 'N/A'
            
            # Price
            price_elem = item.find('span', {'class': 'a-price-whole'})
            product['price'] = price_elem.text.strip() if price_elem else 'N/A'
            
            # Rating
            rating_elem = item.find('span', {'class': 'a-icon-alt'})
            product['rating'] = rating_elem.text.strip() if rating_elem else 'N/A'
            
            # Reviews
            reviews_elem = item.find('span', {'class': 'a-size-base'})
            product['reviews'] = reviews_elem.text.strip() if reviews_elem else 'N/A'
            
            # ASIN (Amazon Standard Identification Number)
            product['asin'] = item.get('data-asin', 'N/A')
            
            # Prime status
            prime_elem = item.find('i', {'class': 'a-icon-prime'})
            product['prime'] = 'Yes' if prime_elem else 'No'
            
            products.append(product)
            print(f"Successfully parsed product: {product['title'][:50]}... | URL: {product['url'][:70]}...")
            
        except Exception as e:
            print(f"Error parsing product: {e}")
            continue
    
    return products

def save_data(products, base_filename='amazon_products'):
    if not products:
        print("No products to save")
        return False
    
    try:
        # Save to CSV
        df = pd.DataFrame(products)
        csv_filename = f'{base_filename}.csv'
        df.to_csv(csv_filename, index=False, encoding='utf-8-sig')  # utf-8-sig for Excel compatibility
        print(f"Successfully saved CSV: {csv_filename}")

        # Save to JSON
        json_filename = f'{base_filename}.json'
        with open(json_filename, 'w', encoding='utf-8') as f:
            json.dump(products, f, ensure_ascii=False, indent=4)
        print(f"Successfully saved JSON: {json_filename}")

        # Save to MAT file
        mat_filename = f'{base_filename}.mat'
        
        # Convert data to a format suitable for MAT file
        mat_data = {
            'titles': np.array([p['title'] for p in products]),
            'prices': np.array([p['price'] for p in products]),
            'ratings': np.array([p['rating'] for p in products]),
            'reviews': np.array([p['reviews'] for p in products]),
            'urls': np.array([p['url'] for p in products]),
            'asins': np.array([p['asin'] for p in products]),
            'prime_status': np.array([p['prime'] for p in products]),
            'keywords': np.array([p.get('keyword', '') for p in products])
        }
        
        sio.savemat(mat_filename, mat_data)
        print(f"Successfully saved MAT file: {mat_filename}")

        # Save URLs separately for easy access
        urls_filename = f'{base_filename}_urls.txt'
        with open(urls_filename, 'w', encoding='utf-8') as f:
            for product in products:
                f.write(f"{product['title'][:100]}...\n{product['url']}\n\n")
        print(f"Successfully saved URLs: {urls_filename}")

        return True
    except Exception as e:
        print(f"Error saving data: {e}")
        return False

def main():
    try:
        # Initialize empty list for all products
        all_products = []
        
        # Setup scraper
        headers = setup_scraper()
        print("Scraper setup completed")
        
        # Define keywords
        keywords = ['laptop', 'ipad', 'iphone', 'AI', 'DSLR']  # Add more keywords as needed
        print(f"Starting scrape for keywords: {keywords}")
        
        # Loop through keywords
        for keyword in keywords:
            print(f"\nScraping data for: {keyword}")
            
            # Get HTML content
            html_content = search_amazon(keyword, headers)
            
            if html_content:
                # Parse products
                products = parse_product_listing(html_content)
                
                # Add keyword to each product and append to all_products
                for product in products:
                    product['keyword'] = keyword
                    all_products.append(product)
                
                print(f"Found {len(products)} products for keyword: {keyword}")
                
                # Add delay between requests
                delay = random.uniform(2, 5)
                print(f"Waiting {delay:.2f} seconds before next request...")
                time.sleep(delay)
            else:
                print(f"No HTML content retrieved for keyword: {keyword}")
        
        # Save results in multiple formats
        if all_products:
            save_data(all_products)
            print(f"Total products collected: {len(all_products)}")
        else:
            print("No products were collected")
            
    except Exception as e:
        print(f"An error occurred in main: {e}")

if __name__ == "__main__":
    main()
# Out:
# Scraper setup completed
# Starting scrape for keywords: ['laptop', 'ipad', 'iphone', 'AI', 'DSLR']
#
# Scraping data for: laptop
# Attempting to fetch URL: https://www.amazon.com/s?k=laptop
# Response status code: 200
# Parsing HTML content...
# Found 22 product items
# Successfully parsed product: Laptop Computer Win 11, 15.6 inch 1920x1080 FHD IP... | URL: https://www.amazon.com/sspa/click?ie=UTF8&spc=MTo4MjkzNzMxODU2MDIzOTA5...
# Successfully parsed product: 15.6 FHD Student Laptop Computer, 16GB RAM 1TB SSD... | URL: https://www.amazon.com/sspa/click?ie=UTF8&spc=MTo4MjkzNzMxODU2MDIzOTA5...
# Successfully parsed product: Acer Aspire 3 A315-24P-R7VH Slim Laptop | 15.6" Fu... | URL: https://www.amazon.com/A315-24P-R7VH-Display-Quad-Core-Processor-Graph...
# Successfully parsed product: HP Newest 14" Ultral Light Laptop for Students and... | URL: https://www.amazon.com/HP-Students-Business-Quad-Core-Storage/dp/B0B2D...
# Successfully parsed product: 15.6 Inch Laptops, Windows 11 Laptop Computer with... | URL: https://www.amazon.com/Naclud-Laptops-Computer-Expandable-Quad-Core/dp...
# Successfully parsed product: HP 14 Laptop, Intel Celeron N4020, 4 GB RAM, 64 GB... | URL: https://www.amazon.com/HP-Micro-edge-Microsoft-14-dq0040nr-Snowflake/d...
# Successfully parsed product: Amazon Basics 17.3-Inch Laptop Computer Shoulder B... | URL: https://www.amazon.com/sspa/click?ie=UTF8&spc=MTo4MjkzNzMxODU2MDIzOTA5...
# Successfully parsed product: ACEMAGIC Laptop Computer, 16GB DDR4 512GB SSD, 15.... | URL: https://www.amazon.com/ACEMAGIC-Computer-Windows-Quad-Core-Battery/dp/...
# Successfully parsed product: ACEMAGIC Laptop, Windows 11 Laptop Computer,16GB D... | URL: https://www.amazon.com/ACEMAGIC-Windows-Computer-Quad-Core-Processor/d...
# Successfully parsed product: HP Portable Laptop, Student and Business, 14" HD D... | URL: https://www.amazon.com/HP-Portable-Student-Business-Quad-Core/dp/B0CPL...
# Successfully parsed product: ACEMAGIC 2024 Newest Gaming Laptop, 16.1-inch FHD ... | URL: https://www.amazon.com/ACEMAGIC-16-1-inch-Processor-Keyboard-Computer/...
# Successfully parsed product: ACEMAGIC Laptop Computer, 16GB DDR4 512GB SSD, 15.... | URL: https://www.amazon.com/sspa/click?ie=UTF8&spc=MTo4MjkzNzMxODU2MDIzOTA5...
# Successfully parsed product: AOC Newest 15.6" Laptop, Intel Quad-Core Processor... | URL: https://www.amazon.com/AOC-Quad-Core-Processor-Computer-Flagship/dp/B0...
# Successfully parsed product: Dell Inspiron 15 3000 3520 Business Laptop Compute... | URL: https://www.amazon.com/Dell-Laptop-Touchscreen-Quad-Core-i5-1135G7/dp/...
# Successfully parsed product: Acer Aspire Go 15 Slim Laptop | 15.6" Full HD IPS ... | URL: https://www.amazon.com/Display-i3-N305-Graphics-Windows-AG15-31P-3947/...
# Successfully parsed product: ACEMAGIC 2024 Newest 17.3Inch Laptop,FHD Display L... | URL: https://www.amazon.com/ACEMAGIC-17-3Inch-Core-12th-Business-Computer/d...
# Successfully parsed product: Laptop Computer 16-inch IPS 16GB DDR4 512GB M.2 22... | URL: https://www.amazon.com/sspa/click?ie=UTF8&spc=MTo4MjkzNzMxODU2MDIzOTA5...
# Successfully parsed product: HP Newest 255 G10 15.6" FHD Business Laptop, AMD R... | URL: https://www.amazon.com/HP-Newest-Business-Numeric-Windows/dp/B0D4RH881...
# Successfully parsed product: jumper Laptop, 4GB DDR4 RAM 128GB SSD, Office 365 ... | URL: https://www.amazon.com/jumper-Subscription-Processor-Computer-Speakers...
# Successfully parsed product: ASUS E410 Intel Celeron N4020 4GB 64GB 14-Inch HD ... | URL: https://www.amazon.com/Intel-Celeron-N4020-14-Inch-Laptop/dp/B09YRY6QC...
# Successfully parsed product: NewLenovo Ideapad 1 Business & Student Laptop 14' ... | URL: https://www.amazon.com/NewLenovo-Business-Display_Intel_Celeron-EMMC-I...
# Successfully parsed product: 15.6'' Laptop Computer,16GB DDR4 1TB SSD,Quad-Core... | URL: https://www.amazon.com/sspa/click?ie=UTF8&spc=MTo4MjkzNzMxODU2MDIzOTA5...
# Found 22 products for keyword: laptop
# Waiting 2.78 seconds before next request...
#
# Scraping data for: ipad
# Attempting to fetch URL: https://www.amazon.com/s?k=ipad
# Response status code: 200
# Parsing HTML content...
# Found 16 product items
# Successfully parsed product: iPad (9th Generation): with A13 Bionic chip, 10.2-... | URL: https://www.amazon.com/2021-Apple-10-2-inch-iPad-Wi-Fi/dp/B09G9FPHY6/r...
# Successfully parsed product: Apple iPad (10.2-Inch, Wi-Fi, 32GB) - Space Gray (... | URL: https://www.amazon.com/Apple-iPad-10-2-Inch-Wi-Fi-32GB/dp/B08264XHCZ/r...
# Successfully parsed product: iPad Air 11-inch (M2): Built for Apple Intelligenc... | URL: https://www.amazon.com/Apple-iPad-Air-11-inch-Intelligence/dp/B0D3J617...
# Successfully parsed product: Apple iPad 2020 (10.2-inch, Wi-Fi, 32GB) - Space G... | URL: https://www.amazon.com/Apple-iPad-10-2-inch-Wi-Fi-32GB/dp/B08KWJW3DV/r...
# Successfully parsed product: Apple iPad (2018 Model) with Wi-Fi only 32GB Apple... | URL: https://www.amazon.com/Renewed-Apple-Model-Wi-Fi-9-7in/dp/B07D3DDJ4L/r...
# Successfully parsed product: iPad Mini (A15 Bionic): 8.3-inch Liquid Retina Dis... | URL: https://www.amazon.com/2021-Apple-iPad-Mini-Wi-Fi/dp/B09G9FW785/ref=sr...
# Successfully parsed product: 2020 Apple iPad (10.2-inch, Wi-Fi, 128GB) - Silver... | URL: https://www.amazon.com/Apple-iPad-10-2-inch-Wi-Fi-128GB/dp/B08KHNGCWY/...
# Successfully parsed product: Apple iPad Air (10.9-inch, Wi-Fi, 256GB) - Green (... | URL: https://www.amazon.com/Apple-iPad-10-9-inch-Wi-Fi-256GB/dp/B08SZ4X379/...
# Successfully parsed product: iPad (10th Generation) 10.9-inch, Wi-Fi 6, 12MP Ba... | URL: https://www.amazon.com/Apple-Generation-10-9-inch-Limited-Warranty/dp/...
# Successfully parsed product: 2018 Apple iPad Pro (12.9-inch, Wi-Fi, 64GB) - Spa... | URL: https://www.amazon.com/Apple-iPad-12-9-inch-Wi-Fi-Generation/dp/B07Q4F...
# Successfully parsed product: Apple iPad Mini 4, 128GB, Silver - WiFi + Cellular... | URL: https://www.amazon.com/iPad-128GB-Silver-Cellular-Refurbished/dp/B0792...
# Successfully parsed product: iPad Pro 13-Inch (M4): Built for Apple Intelligenc... | URL: https://www.amazon.com/Apple-iPad-Pro-13-Inch-Intelligence/dp/B0D3J7ZX...
# Successfully parsed product: 2020 Apple iPad Pro (12.9-inch, Wi-Fi + Cellular, ... | URL: https://www.amazon.com/Apple-12-9-inch-Wi-Fi-Cellular-256GB/dp/B08HH4R...
# Successfully parsed product: Apple iPad Early 2018 (9.7-inch, Wi-Fi, 32GB) - Sp... | URL: https://www.amazon.com/Apple-Early-Wi-Fi-MR7F2LL-Refurbished/dp/B07G9Q...
# Successfully parsed product: iPad Pro 11-Inch (M4): Built for Apple Intelligenc... | URL: https://www.amazon.com/Apple-iPad-Pro-11-Inch-Intelligence/dp/B0D3J96H...
# Successfully parsed product: iPad Pro 12.9-inch (6th Generation): with M2 chip,... | URL: https://www.amazon.com/Apple-12-9-inch-iPad-Pro-Wi-Fi-Cellular/dp/B0BJ...
# Found 16 products for keyword: ipad
# Waiting 3.19 seconds before next request...
#
# Scraping data for: iphone
# Attempting to fetch URL: https://www.amazon.com/s?k=iphone
# Response status code: 200
# Parsing HTML content...
# Found 16 product items
# Successfully parsed product: Apple iPhone XR, US Version, 128GB, Black - Unlock... | URL: https://www.amazon.com/Apple-iPhone-Fully-Unlocked-128/dp/B07P976BBH/r...
# Successfully parsed product: Apple iPhone 7 32GB Unlocked - Silver... | URL: https://www.amazon.com/Apple-iPhone-32GB-Unlocked-Silver/dp/B0CNL4VKWN...
# Successfully parsed product: Apple iPhone 7 32GB Unlocked - Black... | URL: https://www.amazon.com/Apple-iPhone-32GB-Unlocked-Black/dp/B0CNM32TLW/...
# Successfully parsed product: iPhone 8 Plus 64GB Space Gray LTE Cellular MX8X2LL... | URL: https://www.amazon.com/Apple-iPhone-Space-Cellular-MX8X2LL/dp/B0CK55NF...
# Successfully parsed product: Apple iPhone 12 Pro, 128GB, Graphite - AT&T (Renew... | URL: https://www.amazon.com/Apple-iPhone-Pro-128GB-Graphite/dp/B08PNZDQ38/r...
# Successfully parsed product: Apple iPhone SE 16GB Unlocked, 2016 1st Gen, Silve... | URL: https://www.amazon.com/iPhone-64GB-Unlocked-Silver-IPSE64/dp/B09JTRHXW...
# Successfully parsed product: Apple iPhone SE, 16GB 1st Gen 2016 Unlocked, ATT T... | URL: https://www.amazon.com/Apple-iPhone-32GB-Unlocked-Tmobile/dp/B0CKNYFHS...
# Successfully parsed product: Apple iPhone 16 Pro Max (512 GB) - Natural Titaniu... | URL: https://www.amazon.com/Boost-Mobile-Apple-iPhone-Intelligence/dp/B0DGL...
# Successfully parsed product: Azumi iPhone SE 16GB Unlocked, Silver 2016 (Gen 1)... | URL: https://www.amazon.com/iPhone-16GB-Unlocked-Silver-Gen/dp/B097QDTNM5/r...
# Successfully parsed product: Apple iPhone 16 Pro (128 GB) - Black Titanium [Loc... | URL: https://www.amazon.com/Boost-Mobile-Apple-iPhone-Intelligence/dp/B0DGM...
# Successfully parsed product: Apple iPhone 16 (256 GB) - Black [Locked]. Require... | URL: https://www.amazon.com/Boost-Mobile-Apple-iPhone-Intelligence/dp/B0DGL...
# Successfully parsed product: Apple iPhone 16 Plus (128 GB) - Black [Locked]. Re... | URL: https://www.amazon.com/Boost-Mobile-Apple-iPhone-Plus/dp/B0DGLXFJ62/re...
# Successfully parsed product: Apple iPhone 7 32GB Unlocked - Silver & Black - Pr... | URL: https://www.amazon.com/Apple-iPhone-32GB-Unlocked-Excellent/dp/B0D4QK9...
# Successfully parsed product: iPhone 5c 32GB (Green) - Sprint... | URL: https://www.amazon.com/Apple-iPhone-5C-Sprint-Green/dp/B00F3IIVV4/ref=...
# Successfully parsed product: Apple iPhone 12 Mini 5G, US Version, 128GB, Blue -... | URL: https://www.amazon.com/Apple-iPhone-Mini-128GB-Blue/dp/B08PNMBYZ4/ref=...
# Successfully parsed product: Apple iPhone 12, 64GB, Black - Unlocked (Renewed P... | URL: https://www.amazon.com/Apple-iPhone-12-64GB-Black/dp/B09JFNTCLX/ref=sr...
# Found 16 products for keyword: iphone
# Waiting 3.08 seconds before next request...
#
# Scraping data for: AI
# Attempting to fetch URL: https://www.amazon.com/s?k=AI
# Response status code: 200
# Parsing HTML content...
# Found 22 product items
# Successfully parsed product: Generative AI with LangChain: Build large language... | URL: https://www.amazon.com/sspa/click?ie=UTF8&spc=MTozMDM4NDk0ODA4MjM3MzE1...
# Successfully parsed product: AI Voice Recorder, PLAUD Note Voice Recorder w/Cas... | URL: https://www.amazon.com/PLAUD-Transcribe-Summarize-Empowered-Languages/...
# Successfully parsed product: Nexus: A Brief History of Information Networks fro... | URL: https://www.amazon.com/Nexus-Brief-History-Information-Networks/dp/B0C...
# Successfully parsed product: Co-Intelligence: Living and Working with AI... | URL: https://www.amazon.com/Co-Intelligence-Living-Working-Ethan-Mollick/dp...
# Successfully parsed product: AI Voice Recorder, PLAUD Note Voice Recorder w/Cas... | URL: https://www.amazon.com/PLAUD-Transcribe-Summarize-Empowered-Languages/...
# Successfully parsed product: The AI-Driven Leader: Harnessing AI to Make Faster... | URL: https://www.amazon.com/AI-Driven-Leader-Harnessing-Smarter-Decisions/d...
# Successfully parsed product: AI Voice Recorder, PLAUD Note Voice Recorder w/Cas... | URL: https://www.amazon.com/sspa/click?ie=UTF8&spc=MTozMDM4NDk0ODA4MjM3MzE1...
# Successfully parsed product: The Singularity Is Nearer: When We Merge with AI... | URL: https://www.amazon.com/The-Singularity-Is-Nearer/dp/B08ZJRMWVS/ref=sr_...
# Successfully parsed product: Understanding Generative AI for Business Leaders: ... | URL: https://www.amazon.com/Understanding-Generative-Business-Leaders-Demys...
# Successfully parsed product: AI for Business: The Beginner's Fast Track to Chat... | URL: https://www.amazon.com/AI-Business-Beginners-ChatGPT-Productivity/dp/B...
# Successfully parsed product: The Age of AI: And Our Human Future... | URL: https://www.amazon.com/Age-AI-Our-Human-Future/dp/0316273996/ref=sr_1_...
# Successfully parsed product: AI Voice Recorder,64GB Voice Recorder by App Contr... | URL: https://www.amazon.com/sspa/click?ie=UTF8&spc=MTozMDM4NDk0ODA4MjM3MzE1...
# Successfully parsed product: Artificial Intelligence For Dummies (For Dummies (... | URL: https://www.amazon.com/Artificial-Intelligence-Dummies-John-Mueller/dp...
# Successfully parsed product: The AI Edge: Sales Strategies for Unleashing the P... | URL: https://www.amazon.com/AI-Edge-Strategies-Unleashing-Competition/dp/13...
# Successfully parsed product: AI Snake Oil: What Artificial Intelligence Can Do,... | URL: https://www.amazon.com/Snake-Oil-Artificial-Intelligence-Difference/dp...
# Successfully parsed product: Mastering AI: A Survival Guide to Our Superpowered... | URL: https://www.amazon.com/Mastering-AI-Survival-Superpowered-Future/dp/B0...
# Successfully parsed product: AI Voice Recorder, No Fee for Transcription & Summ... | URL: https://www.amazon.com/sspa/click?ie=UTF8&spc=MTozMDM4NDk0ODA4MjM3MzE1...
# Successfully parsed product: Teaching with AI: A Practical Guide to a New Era o... | URL: https://www.amazon.com/Teaching-AI-Practical-Guide-Learning/dp/1421449...
# Successfully parsed product: AI Voice Recorder,64GB Voice Recorder by App Contr... | URL: https://www.amazon.com/Recorder-Processor-Simultaneous-Interpretation-...
# Successfully parsed product: Shark AV2501S AI Ultra Robot Vacuum, with Matrix C... | URL: https://www.amazon.com/Shark-AV2501S-Self-Empty-Navigation-UltraClean/...
# Successfully parsed product: Voice Recorder with Playback, Digital Voice Record... | URL: https://www.amazon.com/sspa/click?ie=UTF8&spc=MTozMDM4NDk0ODA4MjM3MzE1...
# Successfully parsed product: AI Voice Recorder, PLAUD Note Voice Recorder w/Cas... | URL: https://www.amazon.com/sspa/click?ie=UTF8&spc=MTozMDM4NDk0ODA4MjM3MzE1...
# Found 22 products for keyword: AI
# Waiting 3.16 seconds before next request...
#
# Scraping data for: DSLR
# Attempting to fetch URL: https://www.amazon.com/s?k=DSLR
# Response status code: 200
# Parsing HTML content...
# Found 21 product items
# Successfully parsed product: Canon EOS Rebel T7 DSLR Camera with 18-55mm Lens |... | URL: https://www.amazon.com/Canon-Rebel-T7-18-55mm-II/dp/B07C2Z21X5/ref=sr_...
# Successfully parsed product: Canon EOS R100 Mirrorless Camera RF-S18-45mm F4.5-... | URL: https://www.amazon.com/Canon-RF-S18-45mm-RF-S55-210mm-Mirrorless-Light...
# Successfully parsed product: 4K Digital Camera with 40X Zoom，64MP DSLR Camera f... | URL: https://www.amazon.com/Zoom%EF%BC%8C64MP-Photography-Beginners%EF%BC%8...
# Successfully parsed product: Canon DSLR Camera [EOS 90D] with Built-in Wi-Fi, B... | URL: https://www.amazon.com/Canon-Digital-Camera-Black-3616C002/dp/B07WFQYD...
# Successfully parsed product: Canon EOS 4000D / Rebel T100 DSLR Camera w/EF-S 18... | URL: https://www.amazon.com/Canon-18-55mm-3-5-5-6-Filters-Renewed/dp/B0CFSB...
# Successfully parsed product: Canon EOS Rebel T7 DSLR Camera w/EF-S 18-55mm F/3.... | URL: https://www.amazon.com/Canon-420-800mm-Telephoto-Backpack-Professional...
# Successfully parsed product: Canon DSLR Camera [EOS 90D] with 18-135 is USM Len... | URL: https://www.amazon.com/Canon-Digital-Camera-18-135-Lens/dp/B07WHV3HXL/...
# Successfully parsed product: Nikon D7500 20.9MP DSLR Camera with AF-S DX NIKKOR... | URL: https://www.amazon.com/Nikon-20-9MP-Camera-18-140mm-3-5-5-6G/dp/B06Y5R...
# Successfully parsed product: Panasonic LUMIX G95D 20.3 Megapixel Mirrorless Cam... | URL: https://www.amazon.com/Panasonic-Megapixel-Mirrorless-Pre-Installed-To...
# Successfully parsed product: Panasonic LUMIX FZ80D Compact Camera with 20-1200m... | URL: https://www.amazon.com/Panasonic-Compact-20-1200mm-Recording-Stabilize...
# Successfully parsed product: Panasonic LUMIX G7KS 4K Mirrorless Camera, 16 Mega... | URL: https://www.amazon.com/PANASONIC-Mirrorless-14-42mm-Megapixels-DMC-G7K...
# Successfully parsed product: FEELWORLD S55 V3 + Battery + Carry Case 6 Inch DSL... | URL: https://www.amazon.com/sspa/click?ie=UTF8&spc=MTo0MTExODQxMjI1OTA2NjI3...
# Successfully parsed product: Canon EOS R50 Mirrorless Camera RF-S18-45mm F4.5-6... | URL: https://www.amazon.com/Canon-Mirrorless-RF-S18-45mm-Smartphone-Connect...
# Successfully parsed product: Canon EOS R8 Mirrorless Camera RF24-50mm F4.5-6.3 ... | URL: https://www.amazon.com/Canon-Full-Frame-Mirrorless-Smartphone-Connecti...
# Successfully parsed product: Sony ZV-1F Vlog Camera for Content Creators and Vl... | URL: https://www.amazon.com/Sony-Camera-Content-Creators-Vloggers/dp/B0BHKK...
# Successfully parsed product: KODAK PIXPRO AZ405-BK 20MP Digital Camera 40X Opti... | URL: https://www.amazon.com/KODAK-PIXPRO-AZ405-BK-Digital-Optical/dp/B0BLLC...
# Successfully parsed product: BOYA by-V4 Wireless Microphones for Cameras DSLR C... | URL: https://www.amazon.com/sspa/click?ie=UTF8&spc=MTo0MTExODQxMjI1OTA2NjI3...
# Successfully parsed product: Canon EOS Rebel T7 DSLR Camera|2 Lens Kit with EF1... | URL: https://www.amazon.com/Canon-EF18-55mm-75-300mm-Filters-Renewed/dp/B0D...
# Successfully parsed product: Wireless HDMI Transmitter and Receiver, 2.4/5G Sup... | URL: https://www.amazon.com/sspa/click?ie=UTF8&spc=MTo0MTExODQxMjI1OTA2NjI3...
# Successfully parsed product: Portkeys PT6 Camera Field Monitor 5.2" 600nit Touc... | URL: https://www.amazon.com/sspa/click?ie=UTF8&spc=MTo0MTExODQxMjI1OTA2NjI3...
# Successfully parsed product: FEELWORLD F6 Pro +Battery +Charger+Carry Case 5.5 ... | URL: https://www.amazon.com/sspa/click?ie=UTF8&spc=MTo0MTExODQxMjI1OTA2NjI3...
# Found 21 products for keyword: DSLR
# Waiting 3.49 seconds before next request...
# Successfully saved CSV: amazon_products.csv
# Successfully saved JSON: amazon_products.json
# Successfully saved MAT file: amazon_products.mat
# Successfully saved URLs: amazon_products_urls.txt
# Total products collected: 97
